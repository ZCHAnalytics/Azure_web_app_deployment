# %% [markdown]
# ## 6. Managing Resources: Clean up
#
# As I have completed the process of deploying and provisioning resources to Azure, I will delete any unused resources to avoid unexpected costs with the `azd down` command.

# %%
> azd down

# %% [markdown]
# This command typically performs the following tasks:
#
# Stopping Services:
#
# Cleaning Up Resources: It may clean up temporary files, build artifacts, and other resources created during the development process.
#
# Releasing Resources: If the development environment required any reserved resources (e.g., ports, network interfaces), azd down will release those resources.
#
# Finalizing Clean-Up: It completes any remaining clean-up tasks to restore the development environment to its pre-development state.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I check the terminal and see that it deletes resources in this sequenc:
# 1. Deletings the resource group
# 2. Purging the Key Vault
#
# ![image.png](attachment:image.png)
