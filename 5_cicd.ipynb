# %% [markdown]
# # 5. Configure a CI/CD pipeline
#
# The workflows can be automated with a CI/CD pipeline with either GitHub Actions or Azure Pipelines. This way Azure environment can be automatically updated with the latest changes by committing and pushing changes to GitHub.
#
# `azd pipiline config`
#
# ![image.png](attachment:image.png)
#
#
# I create a new repository with the name CICD_pipeline and commit project code to it.
#
# Azd also congifures a service principal for the app on the Azure subscription. It configures a secure connection between Azure and GitHUb repository using the service principal and GitHub secrets.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# All done!

# %% [markdown]
# I want to test the rerun of the CI/CD pipeline after the cleanup. So, I commit new edits in my README file and push changes to remote repository.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# GitHub detects the push event and automatically triggers GitHubActions workflow associated with the repository.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# I click on visual workflow badge called 'build' inside the GitHubActions interface and get the status:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When the the workflow finished, I check the website and can see that there is a websitee called "Ticket |Master".
#
# ![image.png](attachment:image.png)

# %% [markdown]
# I check the Azure portal and see the newly created storage too:
#
# ![image.png](attachment:image.png)
